# %%
import os
import glob
import json
from uuid import uuid4

from pydantic import BaseModel, Field, field_validator

import pymongo
from pymongo import MongoClient

import sqlite3

# %%
base_dir = './'
os.listdir(base_dir)
# Out:
# ['features',
#  'media-info',
#  'download_file_from_gdrive.sh',
#  'dev_write_data_to_db.ipynb',
#  'objects',
#  's_optimized_keyframes',
#  'download_file_from_kaggle.sh',
#  'vid_url.json',
#  'keyframes.csv',
#  'url_fps.json',
#  'README.md']

# %%
os.listdir(os.path.join(base_dir, 'media-info'))
# Out:
# ['L02_V008.json',
#  'L15_V023.json',
#  'L24_V017.json',
#  'L19_V006.json',
#  'L10_V017.json',
#  'L05_V011.json',
#  'L01_V017.json',
#  'L20_V006.json',
#  'L02_V025.json',
#  'L15_V021.json',
#  'L01_V008.json',
#  'L17_V002.json',
#  'L24_V045.json',
#  'L09_V025.json',
#  'L13_V019.json',
#  'L12_V022.json',
#  'L15_V011.json',
#  'L24_V005.json',
#  'L02_V003.json',
#  'L21_V019.json',
#  'L05_V021.json',
#  'L12_V027.json',
#  'L13_V025.json',
#  'L24_V031.json',
#  'L22_V017.json',
#  'L04_V028.json',
#  'L15_V022.json',
#  'L14_V020.json',
#  'L21_V026.json',
#  'L11_V017.json',
#  'L21_V022.json',
#  'L04_V024.json',
#  'L02_V007.json',
#  'L16_V024.json',
#  'L20_V009.json',
#  'L06_V009.json',
#  'L07_V004.json',
#  'L07_V019.json',
#  'L07_V002.json',
#  'L24_V038.json',
#  'L05_V008.json',
#  'L13_V026.json',
#  'L24_V013.json',
#  'L06_V003.json',
#  'L24_V039.json',
#  'L13_V024.json',
#  'L18_V024.json',
#  'L17_V022.json',
#  'L02_V018.json',
#  'L18_V023.json',
#  'L03_V025.json',
#  'L08_V022.json',
#  'L19_V017.json',
#  'L02_V017.json',
#  'L21_V006.json',
#  'L12_V012.json',
#  'L13_V003.json',
#  'L14_V007.json',
#  'L23_V023.json',
#  'L16_V009.json',
#  'L20_V022.json',
#  'L01_V004.json',
#  'L06_V031.json',
#  'L01_V018.json',
#  'L04_V010.json',
#  'L18_V012.json',
#  'L19_V031.json',
#  'L09_V021.json',
#  'L03_V017.json',
#  'L12_V025.json',
#  'L21_V015.json',
#  'L05_V004.json',
#  'L19_V007.json',
#  'L21_V003.json',
#  'L14_V006.json',
#  'L11_V018.json',
#  'L09_V024.json',
#  'L09_V010.json',
#  'L13_V011.json',
#  'L19_V027.json',
#  'L01_V029.json',
#  'L19_V023.json',
#  'L24_V014.json',
#  'L09_V008.json',
#  'L06_V006.json',
#  'L18_V015.json',
#  'L02_V026.json',
#  'L06_V030.json',
#  'L15_V020.json',
#  'L21_V025.json',
#  'L23_V006.json',
#  'L10_V018.json',
#  'L07_V024.json',
#  'L07_V028.json',
#  'L16_V015.json',
#  'L11_V027.json',
#  'L18_V025.json',
#  'L14_V008.json',
#  'L02_V022.json',
#  'L18_V020.json',
#  'L07_V029.json',
#  'L11_V026.json',
#  'L23_V009.json',
#  'L21_V027.json',
#  'L19_V025.json',
#  'L16_V028.json',
#  'L21_V005.json',
#  'L10_V008.json',
#  'L23_V007.json',
#  'L11_V006.json',
#  'L12_V029.json',
#  'L20_V003.json',
#  'L03_V022.json',
#  'L06_V014.json',
#  'L19_V016.json',
#  'L20_V013.json',
#  'L08_V013.json',
#  'L15_V006.json',
#  'L07_V010.json',
#  'L02_V020.json',
#  'L08_V029.json',
#  'L24_V023.json',
#  'L10_V003.json',
#  'L17_V001.json',
#  'L05_V012.json',
#  'L08_V010.json',
#  'L04_V026.json',
#  'L08_V016.json',
#  'L12_V019.json',
#  'L06_V018.json',
#  'L16_V026.json',
#  'L04_V018.json',
#  'L02_V010.json',
#  'L02_V019.json',
#  'L05_V001.json',
#  'L22_V003.json',
#  'L06_V017.json',
#  'L20_V024.json',
#  'L05_V020.json',
#  'L02_V016.json',
#  'L01_V024.json',
#  'L01_V031.json',
#  'L24_V010.json',
#  'L22_V030.json',
#  'L09_V014.json',
#  'L17_V012.json',
#  'L18_V013.json',
#  'L10_V015.json',
#  'L14_V021.json',
#  'L07_V025.json',
#  'L11_V030.json',
#  'L08_V011.json',
#  'L07_V020.json',
#  'L09_V019.json',
#  'L24_V018.json',
#  'L17_V017.json',
#  'L01_V022.json',
#  'L13_V002.json',
#  'L14_V026.json',
#  'L12_V021.json',
#  'L24_V009.json',
#  'L01_V009.json',
#  'L05_V003.json',
#  'L18_V010.json',
#  'L09_V011.json',
#  'L21_V018.json',
#  'L06_V002.json',
#  'L06_V016.json',
#  'L04_V023.json',
#  'L09_V006.json',
#  'L11_V021.json',
#  'L10_V029.json',
#  'L10_V016.json',
#  'L04_V003.json',
#  'L24_V012.json',
#  'L18_V017.json',
#  'L21_V024.json',
#  'L09_V005.json',
#  'L06_V028.json',
#  'L10_V028.json',
#  'L22_V015.json',
#  'L04_V029.json',
#  'L01_V003.json',
#  'L24_V043.json',
#  'L10_V002.json',
#  'L01_V013.json',
#  'L21_V001.json',
#  'L08_V020.json',
#  'L04_V001.json',
#  'L16_V011.json',
#  'L21_V023.json',
#  'L22_V010.json',
#  'L04_V022.json',
#  'L08_V002.json',
#  'L20_V027.json',
#  'L14_V002.json',
#  'L01_V011.json',
#  'L23_V016.json',
#  'L19_V011.json',
#  'L19_V019.json',
#  'L16_V003.json',
#  'L12_V010.json',
#  'L19_V018.json',
#  'L14_V022.json',
#  'L02_V031.json',
#  'L01_V010.json',
#  'L18_V027.json',
#  'L06_V004.json',
#  'L02_V011.json',
#  'L02_V024.json',
#  'L22_V022.json',
#  'L24_V011.json',
#  'L18_V003.json',
#  'L01_V014.json',
#  'L14_V017.json',
#  'L24_V021.json',
#  'L02_V027.json',
#  'L20_V001.json',
#  'L13_V027.json',
#  'L11_V029.json',
#  'L13_V014.json',
#  'L10_V007.json',
#  'L15_V009.json',
#  'L04_V013.json',
#  'L09_V020.json',
#  'L15_V028.json',
#  'L14_V004.json',
#  'L09_V016.json',
#  'L17_V024.json',
#  'L04_V020.json',
#  'L05_V024.json',
#  'L17_V003.json',
#  'L18_V014.json',
#  'L19_V028.json',
#  'L21_V016.json',
#  'L13_V006.json',
#  'L22_V026.json',
#  'L24_V042.json',
#  'L01_V028.json',
#  'L12_V008.json',
#  'L11_V019.json',
#  'L13_V001.json',
#  'L07_V009.json',
#  'L23_V025.json',
#  'L13_V013.json',
#  'L24_V024.json',
#  'L10_V005.json',
#  'L20_V007.json',
#  'L10_V004.json',
#  'L08_V009.json',
#  'L09_V022.json',
#  'L24_V036.json',
#  'L04_V002.json',
#  'L10_V021.json',
#  'L08_V028.json',
#  'L12_V005.json',
#  'L04_V009.json',
#  'L17_V011.json',
#  'L14_V005.json',
#  'L01_V016.json',
#  'L03_V012.json',
#  'L10_V020.json',
#  'L07_V006.json',
#  'L24_V033.json',
#  'L17_V016.json',
#  'L15_V003.json',
#  'L14_V028.json',
#  'L21_V009.json',
#  'L16_V031.json',
#  'L16_V012.json',
#  'L23_V020.json',
#  'L06_V013.json',
#  'L07_V007.json',
#  'L05_V031.json',
#  'L14_V009.json',
#  'L04_V015.json',
#  'L06_V015.json',
#  'L19_V001.json',
#  'L10_V012.json',
#  'L18_V022.json',
#  'L03_V009.json',
#  'L18_V004.json',
#  'L20_V030.json',
#  'L18_V028.json',
#  'L20_V008.json',
#  'L15_V015.json',
#  'L03_V015.json',
#  'L16_V018.json',
#  'L04_V027.json',
#  'L13_V029.json',
#  'L22_V008.json',
#  'L02_V023.json',
#  'L20_V031.json',
#  'L06_V010.json',
#  'L24_V003.json',
#  'L03_V002.json',
#  'L17_V014.json',
#  'L24_V022.json',
#  'L03_V021.json',
#  'L05_V014.json',
#  'L02_V001.json',
#  'L13_V008.json',
#  'L06_V011.json',
#  'L07_V001.json',
#  'L20_V028.json',
#  'L05_V023.json',
#  'L09_V003.json',
#  'L15_V018.json',
#  'L23_V024.json',
#  'L24_V015.json',
#  'L22_V005.json',
#  'L11_V023.json',
#  'L05_V030.json',
#  'L11_V008.json',
#  'L13_V018.json',
#  'L03_V010.json',
#  'L09_V029.json',
#  'L05_V015.json',
#  'L07_V023.json',
#  'L01_V026.json',
#  'L14_V014.json',
#  'L17_V025.json',
#  'L05_V019.json',
#  'L04_V005.json',
#  'L03_V030.json',
#  'L20_V020.json',
#  'L22_V023.json',
#  'L17_V018.json',
#  'L24_V035.json',
#  'L20_V021.json',
#  'L12_V024.json',
#  'L13_V010.json',
#  'L20_V005.json',
#  'L03_V013.json',
#  'L13_V030.json',
#  'L18_V007.json',
#  'L18_V016.json',
#  'L16_V010.json',
#  'L10_V009.json',
#  'L20_V029.json',
#  'L13_V021.json',
#  'L23_V014.json',
#  'L04_V004.json',
#  'L10_V023.json',
#  'L22_V028.json',
#  'L05_V002.json',
#  'L14_V016.json',
#  'L24_V020.json',
#  'L24_V025.json',
#  'L17_V005.json',
#  'L05_V007.json',
#  'L17_V026.json',
#  'L08_V005.json',
#  'L14_V018.json',
#  'L23_V019.json',
#  'L11_V014.json',
#  'L24_V007.json',
#  'L15_V029.json',
#  'L06_V025.json',
#  'L01_V027.json',
#  'L03_V028.json',
#  'L06_V026.json',
#  'L08_V008.json',
#  'L11_V024.json',
#  'L03_V004.json',
#  'L04_V014.json',
#  'L10_V013.json',
#  'L07_V021.json',
#  'L03_V007.json',
#  'L16_V030.json',
#  'L06_V027.json',
#  'L14_V025.json',
#  'L19_V012.json',
#  'L12_V003.json',
#  'L08_V012.json',
#  'L02_V014.json',
#  'L16_V023.json',
#  'L01_V025.json',
#  'L19_V005.json',
#  'L14_V011.json',
#  'L19_V008.json',
#  'L04_V007.json',
#  'L03_V019.json',
#  'L01_V020.json',
#  'L10_V006.json',
#  'L06_V020.json',
#  'L16_V025.json',
#  'L16_V021.json',
#  'L16_V007.json',
#  'L16_V013.json',
#  'L02_V004.json',
#  'L01_V005.json',
#  'L17_V009.json',
#  'L01_V030.json',
#  'L09_V012.json',
#  'L02_V030.json',
#  'L23_V018.json',
#  'L09_V026.json',
#  'L05_V022.json',
#  'L09_V017.json',
#  'L12_V015.json',
#  'L09_V001.json',
#  'L19_V026.json',
#  'L15_V016.json',
#  'L09_V007.json',
#  'L16_V029.json',
#  'L15_V007.json',
#  'L11_V002.json',
#  'L02_V006.json',
#  'L24_V040.json',
#  'L21_V014.json',
#  'L14_V024.json',
#  'L17_V010.json',
#  'L14_V012.json',
#  'L22_V020.json',
#  'L10_V011.json',
#  'L12_V001.json',
#  'L12_V030.json',
#  'L07_V017.json',
#  'L07_V030.json',
#  'L20_V010.json',
#  'L17_V028.json',
#  'L19_V010.json',
#  'L15_V012.json',
#  'L10_V025.json',
#  'L21_V031.json',
#  'L17_V013.json',
#  'L24_V041.json',
#  'L19_V013.json',
#  'L18_V005.json',
#  'L21_V021.json',
#  'L05_V027.json',
#  'L22_V014.json',
#  'L10_V024.json',
#  'L02_V012.json',
#  'L09_V002.json',
#  'L19_V009.json',
#  'L07_V026.json',
#  'L05_V025.json',
#  'L02_V015.json',
#  'L13_V028.json',
#  'L05_V029.json',
#  'L24_V019.json',
#  'L10_V022.json',
#  'L07_V022.json',
#  'L23_V021.json',
#  'L16_V008.json',
#  'L17_V004.json',
#  'L17_V019.json',
#  'L08_V006.json',
#  'L24_V026.json',
#  'L18_V002.json',
#  'L15_V001.json',
#  'L22_V021.json',
#  'L21_V017.json',
#  'L09_V004.json',
#  'L03_V005.json',
#  'L09_V023.json',
#  'L12_V006.json',
#  'L12_V013.json',
#  'L23_V002.json',
#  'L17_V015.json',
#  'L09_V009.json',
#  'L08_V018.json',
#  'L17_V021.json',
#  'L19_V022.json',
#  'L04_V030.json',
#  'L18_V019.json',
#  'L11_V025.json',
#  'L03_V029.json',
#  'L22_V024.json',
#  'L23_V004.json',
#  'L04_V008.json',
#  'L16_V016.json',
#  'L15_V010.json',
#  'L08_V019.json',
#  'L07_V016.json',
#  'L23_V012.json',
#  'L22_V007.json',
#  'L03_V011.json',
#  'L22_V029.json',
#  'L03_V006.json',
#  'L06_V023.json',
#  'L15_V002.json',
#  'L12_V011.json',
#  'L24_V037.json',
#  'L15_V025.json',
#  'L11_V011.json',
#  'L03_V014.json',
#  'L01_V001.json',
#  'L19_V015.json',
#  'L08_V001.json',
#  'L20_V025.json',
#  'L04_V012.json',
#  'L13_V012.json',
#  'L22_V002.json',
#  'L22_V009.json',
#  'L14_V027.json',
#  'L15_V004.json',
#  'L24_V006.json',
#  'L23_V015.json',
#  'L13_V023.json',
#  'L21_V028.json',
#  'L15_V008.json',
#  'L19_V030.json',
#  'L22_V011.json',
#  'L11_V004.json',
#  'L12_V023.json',
#  'L01_V023.json',
#  'L23_V005.json',
#  'L16_V001.json',
#  'L03_V026.json',
#  'L04_V017.json',
#  'L24_V030.json',
#  'L21_V007.json',
#  'L20_V018.json',
#  'L07_V008.json',
#  'L19_V014.json',
#  'L06_V007.json',
#  'L06_V024.json',
#  'L02_V028.json',
#  'L06_V021.json',
#  'L06_V019.json',
#  'L03_V023.json',
#  'L17_V029.json',
#  'L13_V005.json',
#  'L05_V017.json',
#  'L02_V002.json',
#  'L21_V013.json',
#  'L24_V004.json',
#  'L10_V027.json',
#  'L24_V027.json',
#  'L02_V029.json',
#  'L18_V018.json',
#  'L05_V005.json',
#  'L16_V020.json',
#  'L13_V004.json',
#  'L08_V015.json',
#  'L19_V024.json',
#  'L13_V009.json',
#  'L19_V029.json',
#  'L14_V019.json',
#  'L03_V020.json',
#  'L20_V014.json',
#  'L24_V028.json',
#  'L24_V008.json',
#  'L16_V019.json',
#  'L07_V012.json',
#  'L01_V006.json',
#  'L20_V012.json',
#  'L15_V030.json',
#  'L08_V003.json',
#  'L21_V029.json',
#  'L20_V016.json',
#  'L16_V002.json',
#  'L03_V024.json',
#  'L23_V022.json',
#  'L09_V018.json',
#  'L14_V001.json',
#  'L22_V004.json',
#  'L18_V008.json',
#  'L17_V006.json',
#  'L22_V001.json',
#  'L24_V002.json',
#  'L23_V008.json',
#  'L04_V021.json',
#  'L18_V026.json',
#  'L08_V007.json',
#  'L07_V018.json',
#  'L01_V019.json',
#  'L11_V020.json',
#  'L15_V019.json',
#  'L20_V004.json',
#  'L05_V013.json',
#  'L07_V003.json',
#  'L23_V003.json',
#  'L03_V003.json',
#  'L11_V009.json',
#  'L18_V001.json',
#  'L06_V012.json',
#  'L06_V022.json',
#  'L24_V029.json',
#  'L21_V011.json',
#  'L06_V029.json',
#  'L15_V031.json',
#  'L11_V001.json',
#  'L08_V027.json',
#  'L20_V002.json',
#  'L16_V022.json',
#  'L22_V013.json',
#  'L16_V004.json',
#  'L07_V031.json',
#  'L20_V015.json',
#  'L03_V018.json',
#  'L20_V019.json',
#  'L04_V011.json',
#  'L09_V028.json',
#  'L23_V001.json',
#  'L14_V015.json',
#  'L12_V016.json',
#  'L12_V020.json',
#  'L11_V022.json',
#  'L01_V021.json',
#  'L22_V016.json',
#  'L11_V013.json',
#  'L01_V002.json',
#  'L08_V023.json',
#  'L02_V005.json',
#  'L03_V027.json',
#  'L22_V012.json',
#  'L07_V013.json',
#  'L04_V006.json',
#  'L10_V014.json',
#  'L24_V016.json',
#  'L01_V015.json',
#  'L03_V016.json',
#  'L02_V021.json',
#  'L15_V014.json',
#  'L11_V015.json',
#  'L09_V027.json',
#  'L06_V005.json',
#  'L17_V020.json',
#  'L12_V017.json',
#  'L08_V017.json',
#  'L05_V018.json',
#  'L08_V024.json',
#  'L21_V012.json',
#  'L07_V014.json',
#  'L06_V008.json',
#  'L24_V032.json',
#  'L21_V010.json',
#  'L18_V006.json',
#  'L20_V017.json',
#  'L12_V002.json',
#  'L08_V004.json',
#  'L08_V021.json',
#  'L11_V028.json',
#  'L09_V015.json',
#  'L09_V013.json',
#  'L11_V005.json',
#  'L02_V013.json',
#  'L18_V021.json',
#  'L12_V018.json',
#  'L11_V016.json',
#  'L15_V013.json',
#  'L13_V017.json',
#  'L05_V016.json',
#  'L16_V006.json',
#  'L19_V004.json',
#  'L12_V028.json',
#  'L15_V024.json',
#  'L12_V026.json',
#  'L15_V026.json',
#  'L11_V003.json',
#  'L14_V023.json',
#  'L16_V014.json',
#  'L17_V007.json',
#  'L05_V009.json',
#  'L23_V011.json',
#  'L22_V018.json',
#  'L15_V017.json',
#  'L07_V015.json',
#  'L01_V012.json',
#  'L11_V007.json',
#  'L19_V003.json',
#  'L08_V026.json',
#  'L18_V011.json',
#  'L16_V027.json',
#  'L15_V027.json',
#  'L22_V027.json',
#  'L12_V007.json',
#  'L24_V044.json',
#  'L20_V011.json',
#  'L22_V019.json',
#  'L04_V016.json',
#  'L18_V009.json',
#  'L13_V022.json',
#  'L14_V013.json',
#  'L22_V025.json',
#  'L05_V028.json',
#  'L23_V017.json',
#  'L05_V010.json',
#  'L10_V001.json',
#  'L19_V020.json',
#  'L16_V017.json',
#  'L21_V030.json',
#  'L13_V007.json',
#  'L17_V027.json',
#  'L08_V030.json',
#  'L11_V010.json',
#  'L17_V023.json',
#  'L14_V003.json',
#  'L19_V021.json',
#  'L05_V006.json',
#  'L06_V001.json',
#  'L13_V015.json',
#  'L03_V001.json',
#  'L22_V031.json',
#  'L05_V026.json',
#  'L15_V005.json',
#  'L23_V010.json',
#  'L21_V008.json',
#  'L12_V009.json',
#  'L07_V011.json',
#  'L13_V020.json',
#  'L21_V002.json',
#  'L07_V005.json',
#  'L04_V019.json',
#  'L04_V025.json',
#  'L08_V014.json',
#  'L23_V013.json',
#  'L10_V026.json',
#  'L01_V007.json',
#  'L16_V005.json',
#  'L10_V010.json',
#  'L08_V025.json',
#  'L10_V019.json',
#  'L12_V004.json',
#  'L13_V016.json',
#  'L11_V012.json',
#  'L18_V029.json',
#  'L22_V006.json',
#  'L12_V014.json',
#  'L03_V008.json',
#  'L02_V009.json',
#  'L07_V027.json']

# %%
with open(os.path.join(base_dir, 'media-info', 'L02_V008.json'), 'r') as f: 
    json_obj = json.load(f)

json_obj
# Out:
# {'author': '60 Giây Official',
#  'channel_id': 'UCRjzfa1E0gA50lvDQipbDMg',
#  'channel_url': 'https://www.youtube.com/channel/UCRjzfa1E0gA50lvDQipbDMg',
#  'description': '60 Giây Chiều - Ngày 24/10/2023 - HTV Tin Tức Mới Nhất\n► Đăng ký KÊNH để xem Tin Tức Mới Nhất: https://bit.ly/2HoUna4\nKênh Tin Tức Thời Sự 60 Giây Là Kênh Tổng Hợp Tin Tức - Sự Kiện - Giải trí Nhanh Nhất Việt Nam.\n------------\nXem TV online tại Truyền hình HTVC:\n✅ Web / Wap mobile :\n► https://hplus.com.vn\n► https://htvc.com.vn/\n► https://htvc.tv/\n✅ App mobile/TV HTVC :\n► IOS: https://goo.gl/Dih3DB\n► Android: https://goo.gl/XGBzxg\n► Smart TV /STB : Tải HTVC for Android TV\n.\n✅ Theo dõi HTVC trên Mạng xã hội :\n- Facebook Show : https://www.facebook.com/HPlusOfficial\n- Instagram Show : https://www.instagram.com/htvc_truyen_hinh_internet/\n- Lotus Show : https://lotus.vn/w/profile/18444255300272761.htm\n- Tiktok News : https://www.tiktok.com/@htvc.tintuc\n- Tiktok Phim : https://www.tiktok.com/@htvc.phimtruyen\n- Tiktok Show : https://www.tiktok.com/@htvc.truyenhinh\n- Youtube Phim : https://www.youtube.com/c/HplusVn\n- Youtube Phim : https://www.youtube.com/c/HTVCPhim\n- Youtube News : https://www.youtube.com/c/HTV60s\n#TintucthoisuVietnam\n#HTVTintuc\n#HTVnews\n#HTV60s\n#60Giay\n#60s',
#  'keywords': ['HTV Tin tức',
#   'HTV News',
#   'chuong trinh 60 giay',
#   'chuong trinh 60s',
#   'ban tin 60 giay',
#   'ban tin 60s',
#   '60 giay',
#   '60s',
#   '60 giay hom nay',
#   'Tin tức 60 giây',
#   'TIN TUC 60 GIAY',
#   'TIN TỨC 60 GI Y',
#   'tin tuc 60 giay',
#   'tin tức',
#   '60 giây',
#   'Tin Tức',
#   'TIN TUC',
#   '60 GIAY',
#   'Tin Tức Mới',
#   'Tin Tức Mới Nhất',
#   '60 Giây',
#   'HTV Tin Tức',
#   'HTV news',
#   'Xem tin tức mới nhất',
#   'Xem tin tức',
#   'Hôm nay xem gì',
#   '60 giây Sáng',
#   '60 giây chiều',
#   'Bản tin 60s',
#   'Tin tức thời sự việt nam',
#   'Tin tuc thoi su Viet nam'],
#  'length': 1054,
#  'publish_date': '25/10/2023',
#  'thumbnail_url': 'https://i.ytimg.com/vi/s60tzsQcyBE/sddefault.jpg?v=65387f19',
#  'title': '60 Giây Chiều - Ngày 24102023 - HTV Tin Tức Mới Nhất',
#  'watch_url': 'https://youtube.com/watch?v=s60tzsQcyBE'}

# %%
json_obj.keys()
# Out:
# dict_keys(['author', 'channel_id', 'channel_url', 'description', 'keywords', 'length', 'publish_date', 'thumbnail_url', 'title', 'watch_url'])

# %%
kw = ""
for word in json_obj['keywords']: 
    kw += word + " | "

kw
# Out:
# 'HTV Tin tức | HTV News | chuong trinh 60 giay | chuong trinh 60s | ban tin 60 giay | ban tin 60s | 60 giay | 60s | 60 giay hom nay | Tin tức 60 giây | TIN TUC 60 GIAY | TIN TỨC 60 GI Y | tin tuc 60 giay | tin tức | 60 giây | Tin Tức | TIN TUC | 60 GIAY | Tin Tức Mới | Tin Tức Mới Nhất | 60 Giây | HTV Tin Tức | HTV news | Xem tin tức mới nhất | Xem tin tức | Hôm nay xem gì | 60 giây Sáng | 60 giây chiều | Bản tin 60s | Tin tức thời sự việt nam | Tin tuc thoi su Viet nam | '

# %% [markdown]
# # Schema

# %%
class VideoMetadata(BaseModel):
    id: str = Field(default_factory=lambda: str(uuid4()))  # Generate and convert UUID to string
    title: str = Field(..., description="Title of the YouTube video")
    description: str = Field(..., description="Description of the video")
    publish_date: str = Field(..., description="Publication date of the video")
    thumbnail_url: str = Field(..., description="URL of the video thumbnail")
    watch_url: str = Field(..., description="URL to watch the video")
    channel_id: str
    channel_url: str
    author: str
    keywords: str
    length: int
    channel_title: str = Field(None, alias="title")  # For consistency with other fields

    @field_validator('publish_date', mode='before')
    def validate_publish_date(cls, v):
        # Add custom validation for publish_date format if needed
        # For example, using a date parser library
        return v

    @field_validator('keywords', mode='before')
    def validate_keywords(cls, v):
        kw = ""
        v = list(set(v))
        for word in v: 
            kw += word + " | "
        # return list(set(v))
        return kw

class VideoObjects(BaseModel): 
    video_name: str = Field(..., description="The name of the video")
    dtd_objects: list[str] = Field(..., description="A list of detected objects in the video")
    no_dtd_objects: list[int] = Field(..., description="The number of detected objects in the video")

# %%
vd_metadata = VideoMetadata(**json_obj)
vd_metadata.dict()
# Out:
# {'id': '679baeb9-a1ae-48f6-a86c-66725da79307',
#  'title': '60 Giây Chiều - Ngày 24102023 - HTV Tin Tức Mới Nhất',
#  'description': '60 Giây Chiều - Ngày 24/10/2023 - HTV Tin Tức Mới Nhất\n► Đăng ký KÊNH để xem Tin Tức Mới Nhất: https://bit.ly/2HoUna4\nKênh Tin Tức Thời Sự 60 Giây Là Kênh Tổng Hợp Tin Tức - Sự Kiện - Giải trí Nhanh Nhất Việt Nam.\n------------\nXem TV online tại Truyền hình HTVC:\n✅ Web / Wap mobile :\n► https://hplus.com.vn\n► https://htvc.com.vn/\n► https://htvc.tv/\n✅ App mobile/TV HTVC :\n► IOS: https://goo.gl/Dih3DB\n► Android: https://goo.gl/XGBzxg\n► Smart TV /STB : Tải HTVC for Android TV\n.\n✅ Theo dõi HTVC trên Mạng xã hội :\n- Facebook Show : https://www.facebook.com/HPlusOfficial\n- Instagram Show : https://www.instagram.com/htvc_truyen_hinh_internet/\n- Lotus Show : https://lotus.vn/w/profile/18444255300272761.htm\n- Tiktok News : https://www.tiktok.com/@htvc.tintuc\n- Tiktok Phim : https://www.tiktok.com/@htvc.phimtruyen\n- Tiktok Show : https://www.tiktok.com/@htvc.truyenhinh\n- Youtube Phim : https://www.youtube.com/c/HplusVn\n- Youtube Phim : https://www.youtube.com/c/HTVCPhim\n- Youtube News : https://www.youtube.com/c/HTV60s\n#TintucthoisuVietnam\n#HTVTintuc\n#HTVnews\n#HTV60s\n#60Giay\n#60s',
#  'publish_date': '25/10/2023',
#  'thumbnail_url': 'https://i.ytimg.com/vi/s60tzsQcyBE/sddefault.jpg?v=65387f19',
#  'watch_url': 'https://youtube.com/watch?v=s60tzsQcyBE',
#  'channel_id': 'UCRjzfa1E0gA50lvDQipbDMg',
#  'channel_url': 'https://www.youtube.com/channel/UCRjzfa1E0gA50lvDQipbDMg',
#  'author': '60 Giây Official',
#  'keywords': 'chuong trinh 60s | HTV News | 60 giây | Xem tin tức mới nhất | 60 giay hom nay | 60 giây chiều | 60 GIAY | Xem tin tức | 60 giây Sáng | Tin tức thời sự việt nam | HTV news | Tin Tức Mới Nhất | tin tuc 60 giay | chuong trinh 60 giay | 60 Giây | 60 giay | TIN TUC 60 GIAY | Bản tin 60s | Tin Tức Mới | ban tin 60 giay | Hôm nay xem gì | HTV Tin Tức | 60s | HTV Tin tức | Tin Tức | TIN TỨC 60 GI Y | TIN TUC | tin tức | Tin tức 60 giây | Tin tuc thoi su Viet nam | ban tin 60s | ',
#  'length': 1054,
#  'channel_title': '60 Giây Chiều - Ngày 24102023 - HTV Tin Tức Mới Nhất'}

# %%
def video_metadata_factory(cursor, row): 
    fields = [column[0] for column in cursor.description]
    fields = {key: value for key, value in zip(fields, row)}
    fields['keywords'] = fields['keywords'].strip().split(' | ')    # Parse string into list
    return fields

# %% [markdown]
# # Write data

# %%
con = sqlite3.connect("metadata.db")
con.execute("CREATE TABLE IF NOT EXISTS video_metadata (id TEXT PRIMARY KEY, title TEXT NOT NULL, description TEXT NOT NULL, publish_date TEXT NOT NULL, thumbnail_url TEXT NOT NULL, watch_url TEXT NOT NULL, channel_id TEXT NOT NULL, channel_url TEXT NOT NULL, author TEXT NOT NULL, keywords TEXT NOT NULL, length INTEGER NOT NULL, channel_title TEXT);")

# %%
metadata_dir = os.listdir(os.path.join(base_dir, 'media-info'))
data_objects = []
for metadata in metadata_dir: 
    with open(os.path.join(base_dir, 'media-info', metadata), 'r') as f: 
        json_obj = json.load(f)

    # Using this to compress the datasource into our desired configurations
    data = VideoMetadata(**json_obj)
    data_objects.append(data)

len(data_objects)
# Out:
# 726

# %%
data_objects[10].dict()
# Out:
# {'id': 'fd14357e-a1e6-4849-a44b-bd609906aee9',
#  'title': '60 Giây Sáng - Ngày 24102023 - HTV Tin Tức Mới Nhất',
#  'description': '60 Giây Sáng - Ngày 24/10/2023 - HTV Tin Tức Mới Nhất\n► Đăng ký KÊNH để xem Tin Tức Mới Nhất: https://bit.ly/2HoUna4\nKênh Tin Tức Thời Sự 60 Giây Là Kênh Tổng Hợp Tin Tức - Sự Kiện - Giải trí Nhanh Nhất Việt Nam.\n------------\nXem TV online tại Truyền hình HTVC:\n✅ Web / Wap mobile :\n► https://hplus.com.vn\n► https://htvc.com.vn/\n► https://htvc.tv/\n✅ App mobile/TV HTVC :\n► IOS: https://goo.gl/Dih3DB\n► Android: https://goo.gl/XGBzxg\n► Smart TV /STB : Tải HTVC for Android TV\n.\n✅ Theo dõi HTVC trên Mạng xã hội :\n- Facebook Show : https://www.facebook.com/HPlusOfficial\n- Instagram Show : https://www.instagram.com/htvc_truyen_hinh_internet/\n- Lotus Show : https://lotus.vn/w/profile/18444255300272761.htm\n- Tiktok News : https://www.tiktok.com/@htvc.tintuc\n- Tiktok Phim : https://www.tiktok.com/@htvc.phimtruyen\n- Tiktok Show : https://www.tiktok.com/@htvc.truyenhinh\n- Youtube Phim : https://www.youtube.com/c/HplusVn\n- Youtube Phim : https://www.youtube.com/c/HTVCPhim\n- Youtube News : https://www.youtube.com/c/HTV60s\n#TintucthoisuVietnam\n#HTVTintuc\n#HTVnews\n#HTV60s\n#60Giay\n#60s',
#  'publish_date': '24/10/2023',
#  'thumbnail_url': 'https://i.ytimg.com/vi/yvpEq4AltkM/sddefault.jpg?v=65373d81',
#  'watch_url': 'https://youtube.com/watch?v=yvpEq4AltkM',
#  'channel_id': 'UCRjzfa1E0gA50lvDQipbDMg',
#  'channel_url': 'https://www.youtube.com/channel/UCRjzfa1E0gA50lvDQipbDMg',
#  'author': '60 Giây Official',
#  'keywords': 'chuong trinh 60s | HTV News | 60 giây | Xem tin tức mới nhất | 60 giay hom nay | 60 giây chiều | 60 GIAY | Xem tin tức | 60 giây Sáng | Tin tức thời sự việt nam | HTV news | Tin Tức Mới Nhất | tin tuc 60 giay | chuong trinh 60 giay | 60 Giây | 60 giay | TIN TUC 60 GIAY | Bản tin 60s | Tin Tức Mới | ban tin 60 giay | Hôm nay xem gì | HTV Tin Tức | 60s | HTV Tin tức | Tin Tức | TIN TỨC 60 GI Y | TIN TUC | tin tức | Tin tức 60 giây | Tin tuc thoi su Viet nam | ban tin 60s | ',
#  'length': 1186,
#  'channel_title': '60 Giây Sáng - Ngày 24102023 - HTV Tin Tức Mới Nhất'}

# %%
data_holder = []
for data_obj in data_objects: 
    data_holder.append(data_obj.dict())

data_holder = tuple(data_holder)
len(data_holder)
# Out:
# 726

# %%
data_holder[1]
# Out:
# {'id': 'a0e64b8c-95cc-4e69-ad1e-3b746c78dac2',
#  'title': '60 Giây Sáng - Ngày 09052024 - HTV Tin Tức Mới Nhất 2024',
#  'description': '60 Giây Sáng - Ngày 09/05/2024 - HTV Tin Tức Mới Nhất 2024\n► Đăng ký KÊNH để xem Tin Tức Mới Nhất: https://bit.ly/2HoUna4\nKênh Tin Tức Thời Sự 60 Giây Là Kênh Tổng Hợp Tin Tức - Sự Kiện - Giải trí Nhanh Nhất Việt Nam.\n\n©️ Bản quyền Tin Tức thuộc HTV - Đài Truyền hình TP.HCM\n©️ The copyright of this video belongs to HTV - Ho Chi Minh City Television\n#TintucthoisuVietnam\n#HTVTintuc #HTVnews #HTV60s #60Giay #60s\n------------\nXem TV online tại Truyền hình HTVC:\n✅ Web / Wap mobile :\n► https://hplus.com.vn\n► https://htvc.com.vn/\n► https://htvc.tv/\n✅ App mobile/TV HTVC :\n► IOS: https://goo.gl/Dih3DB\n► Android: https://goo.gl/XGBzxg\n► Smart TV /STB : Tải HTVC for Android TV\n.\n✅ Theo dõi HTVC trên Mạng xã hội :\n- Facebook Show : https://www.facebook.com/HPlusOfficial\n- Instagram Show : https://www.instagram.com/htvc_truyen_hinh_internet/\n- Lotus Show : https://lotus.vn/w/profile/18444255300272761.htm\n- Tiktok News : https://www.tiktok.com/@htvc.tintuc\n- Tiktok Phim : https://www.tiktok.com/@htvc.phimtruyen\n- Tiktok Show : https://www.tiktok.com/@htvc.truyenhinh\n- Youtube Phim : https://www.youtube.com/c/HplusVn\n- Youtube Phim : https://www.youtube.com/c/HTVCPhim\n- Youtube News : https://www.youtube.com/c/HTV60s',
#  'publish_date': '09/05/2024',
#  'thumbnail_url': 'https://i.ytimg.com/vi/9JjuqUCYtak/sddefault.jpg?v=663c44d1',
#  'watch_url': 'https://youtube.com/watch?v=9JjuqUCYtak',
#  'channel_id': 'UCRjzfa1E0gA50lvDQipbDMg',
#  'channel_url': 'https://www.youtube.com/channel/UCRjzfa1E0gA50lvDQipbDMg',
#  'author': '60 Giây Official',
#  'keywords': 'chuong trinh 60s | HTV News | 60 giây | Xem tin tức mới nhất | 60 giay hom nay | 60 giây chiều | 60 GIAY | Xem tin tức | 60 giây Sáng | Tin tức thời sự việt nam | HTV news | Tin Tức Mới Nhất | tin tuc 60 giay | chuong trinh 60 giay | 60 Giây | 60 giay | TIN TUC 60 GIAY | Bản tin 60s | Tin Tức Mới | ban tin 60 giay | Hôm nay xem gì | HTV Tin Tức | 60s | HTV Tin tức | Tin Tức | TIN TỨC 60 GI Y | TIN TUC | tin tức | Tin tức 60 giây | Tin tuc thoi su Viet nam | ban tin 60s | ',
#  'length': 1274,
#  'channel_title': '60 Giây Sáng - Ngày 09052024 - HTV Tin Tức Mới Nhất 2024'}

# %%
con.execute("SELECT * FROM video_metadata;").fetchall()
# Out:
# []

# %%
con.executemany("INSERT INTO video_metadata \
                VALUES (:id, :title, :description, :publish_date, :thumbnail_url, :watch_url, :channel_id, :channel_url, :author, :keywords, :length, :channel_title);",data_holder)

# %%
con.row_factory = video_metadata_factory

# %%
con.row_factory = sqlite3.Row

# %%
title = '60 Giây Chiều - Ngày 28032024 - HTV Tin Tức Mới Nhất 2024'
con.execute("SELECT * FROM video_metadata WHERE title = ?", (title, )).fetchmany()[0]
